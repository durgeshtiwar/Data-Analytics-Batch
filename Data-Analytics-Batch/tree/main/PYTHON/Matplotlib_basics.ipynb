# %% [markdown]
# <a href="https://colab.research.google.com/github/durgeshtiwar/Data-Analytics-Batch/blob/main/Data-Analytics-Batch/tree/main/PYTHON/Matplotlib_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2,5,7,8])
y = np.array([8,10,4,7])
plt.plot(x,y)
plt.show()
